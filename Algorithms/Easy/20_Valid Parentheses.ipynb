# %% [markdown]
# # 20. Valid Parentheses
# Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
#
# An input string is valid if:
#
# Open brackets must be closed by the same type of brackets.
# Open brackets must be closed in the correct order.
#
# ## Examples:
# Example 1:
#
# Input: s = "()"
# Output: true
# Example 2:
#
# Input: s = "()[]{}"
# Output: true
# Example 3:
#
# Input: s = "(]"
# Output: false
# Example 4:
#
# Input: s = "([)]"
# Output: false
# Example 5:
#
# Input: s = "{[]}"
# Output: true
#
#
# ## Constraints:
#
# 1 <= s.length <= 104
# s consists of parentheses only '()[]{}'.

# %% [markdown]
# # Josiah's Attempt:
# Runtime: 1960 ms, faster than 5.35% of Python online submissions for Valid Parentheses.
# Memory Usage: 13.7 MB, less than 33.55% of Python online submissions for Valid Parentheses.
# Amazed at how slow this is.

# %%
# Wrong approach: starting from the middle and working its way out...(())[] counter example
def isValid(s):
    """
    :type s: str
    :rtype: bool
    """
    brackets_dict = {"[":"]","{":"}","(":")"}
    if len(s)%2 != 0:
        return False
    
    mid_point = len(s)//2-1
    for i in range(mid_point):
        print(s[mid_point]+ s[mid_point+1])
        try:
            if brackets_dict[s[mid_point]] == s[mid_point+1]:
                s = s.replace(s[mid_point+1],'',1).replace(s[mid_point-i],'',1)
                mid_point-=1
                continue
        except:
            return False
        return False
    return True

# %%
# Wrong approach: finding match from the left and deleting match. This mess up the structure and ordering.
def isValid(s):
    """
    :type s: str
    :rtype: bool
    """
    brackets_dict = {"[":"]","{":"}","(":")"}
    if len(s)%2 != 0:
        return False
    
    mid_point = len(s)//2
    if len(s)>2:
        for i in range(mid_point):
            for j in range(mid_point):
                if s[i] == s[i+j]:
                    s = s.replace(brackets_dict[s[i]],'',1).replace(s[i],'',1)
                    
    print(s)
    
    if len(s)>2:
        return False
    elif brackets_dict[s[0]]==s[1]:
        return True
    return False

# %%
# Super slow but works ¬.¬
def isValid(s):
    """
    :type s: str
    :rtype: bool
    """
    brackets_pair = ["()","{}","[]"]
    if len(s)%2 != 0:
        return False
    a = True
    temp_s = s
    while s!= '':
        for i in range(len(s)):
            if s[i:i+2] in brackets_pair:
                s = s.replace(s[i:i+2],'',1)
        if s == temp_s:
            a = False
            break
            
        temp_s = s
    return a
